# %% [markdown]
# # 02 — Voting Exploration
#
# **Tweede Kamer Open Data · Speech-to-Vote Project**
#
# Explore voting data: votes per party, Voor/Tegen rates, party cohesion.
# **Baseline 1**: How predictable are votes from party alone? (majority-class baseline)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = Path("../data/processed")

stemming = pd.read_parquet(DATA_DIR / "Stemming.parquet")
besluit = pd.read_parquet(DATA_DIR / "Besluit.parquet")
agendapunt = pd.read_parquet(DATA_DIR / "Agendapunt.parquet")
fractie = pd.read_parquet(DATA_DIR / "Fractie.parquet")

print(f"Stemming: {len(stemming):,} votes")
print(f"Besluit: {len(besluit):,} decisions")
print(f"Agendapunt: {len(agendapunt):,} agenda items")

# %% [markdown]
# ## Vote distribution (Voor / Tegen / Niet deelgenomen)

# %%
vote_counts = stemming['Soort'].value_counts()
print(vote_counts)
vote_counts.plot(kind='bar', title='Vote distribution')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Join votes with Besluit and Agendapunt

# %%
# Only Besluiten that have votes
besluit_ids = stemming['Besluit_Id'].dropna().unique()
besluit_voted = besluit[besluit['Id'].isin(besluit_ids)]

votes_joined = stemming.merge(
    besluit_voted[['Id', 'Agendapunt_Id', 'BesluitSoort', 'BesluitTekst', 'StemmingsSoort']],
    left_on='Besluit_Id',
    right_on='Id',
    how='inner',
    suffixes=('', '_besluit')
)
print(f"Votes with Besluit context: {len(votes_joined):,}")

# %% [markdown]
# ## Votes per party (ActorFractie)

# %%
party_votes = votes_joined.groupby('ActorFractie')['Soort'].value_counts().unstack(fill_value=0)
party_votes['total'] = party_votes.sum(axis=1)
party_votes = party_votes.sort_values('total', ascending=False)
party_votes.head(15)

# %%
# Voor/Tegen rate per party (excluding Niet deelgenomen for simplicity)
vt = votes_joined[votes_joined['Soort'].isin(['Voor', 'Tegen'])]
vt_party = vt.groupby('ActorFractie')['Soort'].value_counts().unstack(fill_value=0)
vt_party['voor_pct'] = (vt_party['Voor'] / (vt_party['Voor'] + vt_party['Tegen']) * 100).round(1)
vt_party = vt_party.sort_values('Voor', ascending=False)
vt_party.head(15)

# %% [markdown]
# ## Baseline 1: Party-only prediction
#
# **Question**: If we always predict the majority vote of the party, what accuracy do we get?
#
# This is the lower bound — how much does party membership alone explain?

# %%
# Per Besluit, per party: what did the party vote? (majority)
# For each vote record: predict party majority, compare to actual

def party_majority_vote(votes_df):
    """For each (Besluit_Id, ActorFractie), get the majority vote (Voor/Tegen/Niet)."""
    vt = votes_df[votes_df['Soort'].isin(['Voor', 'Tegen', 'Niet deelgenomen'])]
    def mode_or_first(x):
        m = x.mode()
        return m.iloc[0] if len(m) > 0 else x.iloc[0]
    counts = vt.groupby(['Besluit_Id', 'ActorFractie'])['Soort'].agg(mode_or_first)
    return counts.reset_index().rename(columns={'Soort': 'party_majority'})

majority = party_majority_vote(votes_joined)
votes_with_majority = votes_joined.merge(
    majority,
    on=['Besluit_Id', 'ActorFractie'],
    how='left'
)
votes_with_majority = votes_with_majority[votes_with_majority['party_majority'].notna()]

correct = (votes_with_majority['Soort'] == votes_with_majority['party_majority']).sum()
total = len(votes_with_majority)
acc = correct / total * 100 if total > 0 else 0

print(f"Baseline 1 (party majority): {correct:,} / {total:,} correct = {acc:.2f}% accuracy")
print(f"\nInterpretation: Party alone explains ~{acc:.0f}% of votes. Speech text must add value beyond this.")

# %%
# Per-party accuracy of party-majority baseline
votes_with_majority['correct'] = votes_with_majority['Soort'] == votes_with_majority['party_majority']
party_acc = votes_with_majority.groupby('ActorFractie')['correct'].agg(['mean', 'sum', 'count'])
party_acc.columns = ['accuracy', 'correct', 'total']
party_acc = party_acc.sort_values('total', ascending=False)
party_acc['accuracy_pct'] = (party_acc['accuracy'] * 100).round(1)
party_acc.head(15)

# %% [markdown]
# ## Party cohesion over time (if we have date info)
#
# Note: Stemming doesn't have date directly; we'd need to join via Besluit -> Agendapunt -> Activiteit.

# %%
# Check if we can get date from Besluit/Agendapunt/Activiteit
activiteit = pd.read_parquet(DATA_DIR / "Activiteit.parquet")
if 'Datum' in activiteit.columns:
    ap_act = agendapunt.merge(
        activiteit[['Id', 'Datum']].rename(columns={'Id': 'Activiteit_Id_act'}),
        left_on='Activiteit_Id', right_on='Activiteit_Id_act', how='left'
    )
    besluit_ap = besluit_voted.merge(
        ap_act[['Id', 'Datum']],
        left_on='Agendapunt_Id', right_on='Id', how='left', suffixes=('', '_ap')
    )
    votes_with_date = votes_joined.merge(
        besluit_ap[['Id', 'Datum']].rename(columns={'Id': 'Besluit_Id_bp'}),
        left_on='Besluit_Id', right_on='Besluit_Id_bp', how='left'
    )
    votes_with_date['year'] = pd.to_datetime(votes_with_date['Datum'], errors='coerce').dt.year
    print("Years in data:", sorted(votes_with_date['year'].dropna().astype(int).unique()))
else:
    print("No Datum in Activiteit")

# %% [markdown]
# ## Time Series: Speeches and Voting Moments
#
# How does parliamentary activity evolve over time? Monthly counts of speeches delivered and unique voting moments (besluiten).

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
from pathlib import Path

ANALYSIS_DIR = Path("../data/analysis")
pairs = pd.read_parquet(ANALYSIS_DIR / "speech_vote_pairs.parquet")
pairs['datum'] = pd.to_datetime(pairs['datum'], errors='coerce')
pairs['month'] = pairs['datum'].dt.to_period('M')

speeches_per_month = pairs.groupby('month').size().rename('speeches')
votes_per_month = pairs.groupby('month')['besluit_id'].nunique().rename('voting_moments')

ts = pd.concat([speeches_per_month, votes_per_month], axis=1)
ts.index = ts.index.to_timestamp()

fig, ax1 = plt.subplots(figsize=(14, 5))

color_speech = '#2563eb'
color_vote = '#dc2626'

ax1.fill_between(ts.index, ts['speeches'], alpha=0.15, color=color_speech)
ax1.plot(ts.index, ts['speeches'], color=color_speech, linewidth=1.5, label='Speeches')
ax1.set_ylabel('Speeches (linked to votes)', color=color_speech)
ax1.tick_params(axis='y', labelcolor=color_speech)

ax2 = ax1.twinx()
ax2.plot(ts.index, ts['voting_moments'], color=color_vote, linewidth=1.5, label='Voting moments')
ax2.set_ylabel('Unique voting moments (besluiten)', color=color_vote)
ax2.tick_params(axis='y', labelcolor=color_vote)

ax1.xaxis.set_major_locator(mdates.YearLocator())
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax1.set_xlabel('')
ax1.set_title('Monthly Parliamentary Activity: Speeches & Voting Moments')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left', framealpha=0.9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Voor / Tegen Balance Over Time
#
# Monthly proportion of "Voor" votes — does the government's success rate shift across parliamentary periods?

# %%
vt = pairs[pairs['vote'].isin(['Voor', 'Tegen'])].copy()
vt['is_voor'] = (vt['vote'] == 'Voor').astype(int)

monthly_balance = vt.groupby('month').agg(
    voor_pct=('is_voor', 'mean'),
    total=('is_voor', 'size')
)
monthly_balance.index = monthly_balance.index.to_timestamp()
monthly_balance['voor_pct'] *= 100

# 3-month rolling average for smoothing
monthly_balance['voor_rolling'] = monthly_balance['voor_pct'].rolling(3, center=True).mean()

fig, ax = plt.subplots(figsize=(14, 4))

ax.bar(monthly_balance.index, monthly_balance['voor_pct'],
       width=25, alpha=0.3, color='#16a34a', label='Monthly % Voor')
ax.plot(monthly_balance.index, monthly_balance['voor_rolling'],
        color='#15803d', linewidth=2, label='3-month rolling avg')
ax.axhline(50, color='grey', linestyle='--', linewidth=0.8, alpha=0.6)

ax.set_ylabel('% Voor (of Voor + Tegen)')
ax.set_title('Monthly Vote Balance: Proportion Voting "Voor"')
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.set_ylim(30, 80)
ax.legend(loc='upper right', framealpha=0.9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Speeches by Debate Type Over Time
#
# Stacked area chart showing which types of parliamentary debates generate speech-vote pairs (plenair debat, stemmingen, commissiedebat, etc.).

# %%
TOP_N = 5
top_types = pairs['activiteit_soort'].value_counts().head(TOP_N).index.tolist()
pairs_typed = pairs[pairs['activiteit_soort'].isin(top_types)].copy()

type_monthly = (
    pairs_typed
    .groupby(['month', 'activiteit_soort'])
    .size()
    .unstack(fill_value=0)
)
type_monthly.index = type_monthly.index.to_timestamp()

# Quarterly resample for cleaner stacked area
type_quarterly = type_monthly.resample('QS').sum()

colors = ['#2563eb', '#dc2626', '#f59e0b', '#10b981', '#8b5cf6']

fig, ax = plt.subplots(figsize=(14, 5))
ax.stackplot(type_quarterly.index, *[type_quarterly[c] for c in type_quarterly.columns],
             labels=type_quarterly.columns, colors=colors, alpha=0.75)

ax.set_ylabel('Speech-vote pairs per quarter')
ax.set_title('Parliamentary Activity by Debate Type (quarterly)')
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.legend(loc='upper left', framealpha=0.9, fontsize=9)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Vergaderjaar Comparison
#
# Aggregate speech and vote counts by parliamentary year (e.g. 2021-2022), the natural unit of Dutch parliamentary cycles.

# %%
vjaar = pairs.groupby('vergaderjaar').agg(
    speeches=('speech_text', 'size'),
    voting_moments=('besluit_id', 'nunique'),
    speakers=('persoon_id', 'nunique'),
    avg_speech_len=('speech_length', 'mean')
).sort_index()

fig, axes = plt.subplots(1, 3, figsize=(16, 5))

axes[0].bar(vjaar.index, vjaar['speeches'], color='#2563eb', alpha=0.8)
axes[0].set_title('Speech-Vote Pairs')
axes[0].tick_params(axis='x', rotation=45)
axes[0].set_ylabel('Count')

axes[1].bar(vjaar.index, vjaar['voting_moments'], color='#dc2626', alpha=0.8)
axes[1].set_title('Unique Voting Moments')
axes[1].tick_params(axis='x', rotation=45)

axes[2].bar(vjaar.index, vjaar['speakers'], color='#8b5cf6', alpha=0.8)
axes[2].set_title('Unique Speakers')
axes[2].tick_params(axis='x', rotation=45)

fig.suptitle('Activity per Vergaderjaar (Parliamentary Year)', fontsize=13, y=1.02)
plt.tight_layout()
plt.show()

print(vjaar.to_string())

# %% [markdown]
# ## Party Cohesion Over Time
#
# Do parties become more or less disciplined over the years? Track party cohesion (% of members voting with the party majority) per vergaderjaar for the largest parties.

# %%
vt_pairs = pairs[pairs['vote'].isin(['Voor', 'Tegen'])].copy()

party_majority = (
    vt_pairs
    .groupby(['vergaderjaar', 'besluit_id', 'fractie'])['vote']
    .agg(lambda x: x.mode().iloc[0])
    .rename('party_majority')
)
vt_merged = vt_pairs.merge(
    party_majority.reset_index(),
    on=['vergaderjaar', 'besluit_id', 'fractie'],
    how='left'
)
vt_merged['with_majority'] = vt_merged['vote'] == vt_merged['party_majority']

top_parties = vt_pairs['fractie'].value_counts().head(8).index.tolist()

cohesion = (
    vt_merged[vt_merged['fractie'].isin(top_parties)]
    .groupby(['vergaderjaar', 'fractie'])['with_majority']
    .mean()
    .unstack()
    * 100
)

fig, ax = plt.subplots(figsize=(14, 5))
for party in cohesion.columns:
    ax.plot(cohesion.index, cohesion[party], marker='o', markersize=4, linewidth=1.5, label=party)

ax.set_ylabel('Cohesion (% voting with party majority)')
ax.set_title('Party Cohesion Over Time (top 8 parties)')
ax.set_ylim(85, 101)
ax.tick_params(axis='x', rotation=45)
ax.legend(bbox_to_anchor=(1.02, 1), loc='upper left', fontsize=9)

plt.tight_layout()
plt.show()
